# %%
# Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datasets import load_dataset

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Cleaning Data
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df_uk = df[df['job_country'] == 'United Kingdom'].copy()
df_uk['job_posted_month'] = df_uk['job_posted_date'].dt.strftime('%B')

df_uk_pivot = df_uk.pivot_table(
    index='job_posted_month',
    columns='job_title_short',
    aggfunc='size'
)
df_uk_pivot = df_uk_pivot.reset_index()
df_uk_pivot['month_no'] = pd.to_datetime(df_uk_pivot['job_posted_month'],
                                         format='%B').dt.month
df_uk_pivot = df_uk_pivot.sort_values('month_no')
df_uk_pivot = df_uk_pivot.set_index('job_posted_month')
df_uk_pivot = df_uk_pivot.drop(columns='month_no')

# %%
df_uk_pivot
# Out:
# job_title_short   Business Analyst  ...  Software Engineer
# job_posted_month                    ...
# January                         46  ...                 20
# February                        23  ...                 10
# March                           47  ...                 19
# April                           29  ...                 18
# May                             23  ...                 16
# June                            14  ...                  4
# July                            38  ...                 12
# August                          22  ...                 13
# September                      111  ...                116
# October                        195  ...                126
# November                       155  ...                 90
# December                       124  ...                 97
#
# [12 rows x 10 columns]

# %%
df_uk_software_pivot = pd.read_csv('https://lukeb.co/software_csv',
                                   index_col='job_posted_month')
df_uk_software_pivot
# Out:
#                   Front-End Developer  ...  UI/UX Designer
# job_posted_month                       ...
# January                         13619  ...            4348
# February                        11456  ...            4284
# March                           11102  ...            4159
# April                           14037  ...            4220
# May                             12126  ...            4980
# June                            12003  ...            4781
# July                            11914  ...            4344
# August                          11571  ...            4104
# September                       14016  ...            4094
# October                         11419  ...            4389
# November                        13771  ...            4099
# December                        14033  ...            4367
#
# [12 rows x 4 columns]

# %%
df_uk_merged = df_uk_pivot.merge(df_uk_software_pivot, on='job_posted_month')
df_uk_merged
# Out:
#                   Business Analyst  ...  UI/UX Designer
# job_posted_month                    ...
# January                         46  ...            4348
# February                        23  ...            4284
# March                           47  ...            4159
# April                           29  ...            4220
# May                             23  ...            4980
# June                            14  ...            4781
# July                            38  ...            4344
# August                          22  ...            4104
# September                      111  ...            4094
# October                        195  ...            4389
# November                       155  ...            4099
# December                       124  ...            4367
#
# [12 rows x 14 columns]

# %%
top_5 = (
    df_uk_merged
    .sum()
    .sort_values(ascending=False)
    .head()
    .index
    .tolist()
)
top_5
# Out:
# ['Front-End Developer',
#  'Back-End Developer',
#  'Full-Stack Developer',
#  'UI/UX Designer',
#  'Data Engineer']

# %%
df_uk_merged[top_5].plot(kind='line')
plt.title('Monthly Job Postings for Tech Jobs in the UK')
plt.xlabel('2023')
plt.ylabel('Job Count')
plt.ylim(0, 20000)
plt.legend();
